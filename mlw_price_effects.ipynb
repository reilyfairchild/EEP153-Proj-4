# %% [markdown]
# ## Costs

# %% [markdown]
# ### Preface

# %% [markdown]
# There are a few modules you may need to install (but avoid this if you can; you may need to restart your kernel afterwards):

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: CFEDemands>=0.6.3.dev0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.6.4.dev0)
# Requirement already satisfied: ConsumerDemands>=0.4.3.dev0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.4.3.dev0)
# Requirement already satisfied: matplotlib>=3.3.4 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (3.10.1)
# Requirement already satisfied: numpy>=1.21.5 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (2.2.5)
# Requirement already satisfied: pandas>=1.3.5 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (2.2.3)
# Requirement already satisfied: plotly>=5.1.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (6.0.1)
# Requirement already satisfied: eep153_tools>=0.11 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (0.12.4)
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (0.5.4)
# Requirement already satisfied: gspread_pandas>=3.3 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (3.3.0)
# Requirement already satisfied: scikit-learn in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (1.6.0)
# Requirement already satisfied: xarray in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (2025.1.1)
# Requirement already satisfied: scipy>=1.7.3 in /srv/conda/lib/python3.11/site-packages (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: importlib_metadata>=6.7.0 in /srv/conda/lib/python3.11/site-packages (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (8.6.1)
# Requirement already satisfied: fsspec in /srv/conda/lib/python3.11/site-packages (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (2025.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (24.2)
# Requirement already satisfied: pillow>=8 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/lib/python3.11/site-packages (from plotly>=5.1.0->-r requirements.txt (line 23)) (1.35.0)
# Requirement already satisfied: gspread<6,>=5.0.0 in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.12.4)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.1.1)
# Requirement already satisfied: google-auth in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.39.0)
# Requirement already satisfied: google-auth-oauthlib in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (1.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /srv/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 30)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /srv/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 30)) (3.6.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.11/site-packages (from google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.0.0)
# Requirement already satisfied: zipp>=3.20 in /srv/conda/lib/python3.11/site-packages (from importlib_metadata>=6.7.0->CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (3.21.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /srv/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2025.1.31)

# %% [markdown]
# We import critical objects from `example_nutrition.py`, avoiding the need to do so in this notebook.  These are for Uganda:

# %%
from example_nutrition import r as mlw
from example_nutrition import rdi, nutrient_demand
# Out:
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -1.16E-10.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))
# n                           Energy  Protein  Fiber  Folate  Calcium  \
# j
# apple                         52.0      0.3    2.4     3.0      6.0
# avocado                      160.0      2.0    6.7    81.0     12.0
# banana                        89.0      1.1    2.6    20.0      5.0
# bean, brown                  127.0      8.7    6.4   130.0     28.0
# bean, white                  139.0      9.7    6.3   140.0     90.0
# ...                            ...      ...    ...     ...      ...
# wine or commercial liquor     70.0      0.0    0.0     0.0      0.0
# yeast, baking powder, bica    50.0      5.0    0.0   100.0     50.0
# yoghurt                       59.0      3.5    0.0     7.0    121.0
# zikondamoyo/nkate            500.0     10.0    5.0    50.0     50.0
# zikondamoyo/nkate            500.0     10.0    5.0    50.0     50.0
#
# n                           Carbohydrate  Iron  Niacin  Riboflavin  Thiamin  \
# j
# apple                               14.0   0.1     0.1        0.03     0.02
# avocado                              9.0   0.6     1.7        0.13     0.07
# banana                              23.0   0.3     0.7        0.07     0.03
# bean, brown                         22.0   2.5     0.9        0.10     0.20
# bean, white                         25.0   2.7     0.9        0.10     0.20
# ...                                  ...   ...     ...         ...      ...
# wine or commercial liquor            2.0   0.0     0.0        0.00     0.00
# yeast, baking powder, bica          10.0   1.0     5.0        0.50     0.50
# yoghurt                              4.7   0.1     0.1        0.14     0.04
# zikondamoyo/nkate                   80.0   2.0     2.0        0.20     0.30
# zikondamoyo/nkate                   80.0   2.0     2.0        0.20     0.30
#
# n                           Vitamin A  Vitamin B-12  Vitamin B-6  Vitamin C  \
# j
# apple                            54.0           0.0         0.04        4.6
# avocado                         146.0           0.0         0.26       10.0
# banana                           64.0           0.0         0.37        8.7
# bean, brown                       0.0           0.0         0.20        1.2
# bean, white                       0.0           0.0         0.20        1.2
# ...                               ...           ...          ...        ...
# wine or commercial liquor         0.0           0.0         0.00        0.0
# yeast, baking powder, bica        0.0           0.0         0.50        0.0
# yoghurt                          99.0           0.4         0.05        0.5
# zikondamoyo/nkate                 0.0           0.0         0.20        0.0
# zikondamoyo/nkate                 0.0           0.0         0.20        0.0
#
# n                           Zinc
# j
# apple                       0.04
# avocado                     0.60
# banana                      0.20
# bean, brown                 1.00
# bean, white                 1.10
# ...                          ...
# wine or commercial liquor   0.00
# yeast, baking powder, bica  1.00
# yoghurt                     0.60
# zikondamoyo/nkate           1.00
# zikondamoyo/nkate           1.00
#
# [154 rows x 15 columns]
# Index([], dtype='object', name='j')
# Number of goods in alignment: 47
# Total quantity demanded (sum): 35.18735883022105
# Total nutrients available:
#  n
# Protein        287.480323
# Energy        6407.264292
# Iron            43.311485
# Vitamin A    25816.630453
# dtype: float64
# Common goods: Index(['avocado', 'banana', 'bean, brown', 'beef', 'biscuits', 'bread',
#        'buns, scones', 'cabbage', 'cassava tubers', 'chinese cabbage',
#        'chips (vendor)', 'cooking oil', 'eggs', 'fresh fish (medium variety)',
#        'fresh fish (small variety)', 'fresh milk', 'fruit juice', 'goat',
#        'green maize', 'groundnut flour', 'irish potato',
#        'maize ufa mgaiwa (normal flour)', 'maize ufa refined (fine flour)',
#        'mandazi, doughnut (vendor)', 'onion', 'orange sweet potato', 'popcorn',
#        'powdered milk', 'rice', 'salt', 'samosa (vendor)',
#        'smoked fish (medium variety)', 'smoked fish (small variety)',
#        'soyabean flour', 'spaghetti, macaroni, pasta', 'spices', 'sugar',
#        'sugar cane', 'sun dried fish (large variety)',
#        'sun dried fish (medium variety)', 'sun dried fish (small variety)',
#        'sweets, candy, chocolates', 'tea', 'thobwa', 'tomato',
#        'white sweet potato', 'yoghurt'],
#       dtype='object', name='j')
# Nutrient demand:
#  n
# Protein        287.480323
# Energy        6407.264292
# Iron            43.311485
# Vitamin A    25816.630453
# dtype: float64
# Missing nutrient entries:
#  n
# Protein      0
# Energy       0
# Iron         0
# Vitamin A    0
# dtype: int64
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -1.16E-10.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -7.28E-12.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))

# %%
import cfe.regression as rgsn
r = rgsn.read_pickle('malawi_estimates.rgsn')
print(r.beta.index)
# Out:
# Index(['Avocado', 'Banana', 'Bean, brown', 'Beef', 'Biscuits', 'Bread',
#        'Buns, scones', 'Cabbage', 'Cassava tubers', 'Chicken - whole',
#        'Chinese cabbage', 'Chips (vendor)', 'Citrus – naartje, orange, etc',
#        'Cooking oil', 'Eggs', 'Fresh fish (medium variety)',
#        'Fresh fish (small variety)', 'Fresh milk', 'Fruit juice', 'Goat',
#        'Green maize', 'Groundnut (shelled)', 'Groundnut flour', 'Irish potato',
#        'Maize - boiled or roasted (vendor)', 'Maize ufa mgaiwa (normal flour)',
#        'Maize ufa refined (fine flour)', 'Mandazi, doughnut (vendor)',
#        'Margarine - blue band', 'Nkhwani', 'Okra / therere', 'Onion',
#        'Orange sweet potato', 'Other cultivated green leafy vegetables',
#        'Popcorn', 'Powdered milk', 'Rice', 'Salt', 'Samosa (vendor)',
#        'Smoked fish (medium variety)', 'Smoked fish (small variety)',
#        'Soft drinks (coca-cola, fanta, sprite, etc)', 'Soyabean flour',
#        'Spaghetti, macaroni, pasta', 'Spices',
#        'Squash (sobo drink concentrate)', 'Sugar', 'Sugar cane',
#        'Sun dried fish (large variety)', 'Sun dried fish (medium variety)',
#        'Sun dried fish (small variety)', 'Sweets, candy, chocolates',
#        'Tanaposi/rape', 'Tea', 'Thobwa', 'Tomato', 'White sweet potato',
#        'Wild fruit (masau, malambe, etc)',
#        'Yeast, baking powder, bicarbonate of soda', 'Yoghurt'],
#       dtype='object', name='j')

# %%
print(r.predicted_expenditures())
# Out:
# i             t        m         j
# 101011000071  2019-20  North     Avocado                                       383.113800
#                                  Banana                                        494.138806
#                                  Bean, brown                                   635.824825
#                                  Beef                                         2522.707026
#                                  Biscuits                                      453.344044
#                                                                                  ...
# 315538160239  2019-20  Southern  Tomato                                        348.301365
#                                  White sweet potato                            293.415618
#                                  Wild fruit (masau, malambe, etc)              128.500366
#                                  Yeast, baking powder, bicarbonate of soda      38.553488
#                                  Yoghurt                                       479.050683
# Length: 269340, dtype: float64

# %% [markdown]
# ## Analysis
#
# #### 2019-2020
#
# When using beef as our good of interest, we get some good insight into how price changes affect the nutrition adequacy ratio. The last graph indicates that for a drop in price from 2000 to 1000, we see a drop in log nutrient adequacy ratio from -2.7 to -2.3, which is approximately a 40% increase in nutrient adequacy ratio. We also diminishing marginal returns from increasing the budget, so increasing the budget past our current threshold has small increases to the log nutritional adequacy ratio. We also see sharp decreases for specific nutrients from increases in log price from 0 - 1, indicating the importance of theses goods in making nutritional adequacy affordable and accessible to the population of Malawi.  The strong effect of price changes, but a small income effect, indicates a strong substitution effect when it comes to these goods. Directly lowering the price through policy measures that increase the supply of food or make it more price competitive with other options.

# %% [markdown]
# ### Ceteris Paribus

# %% [markdown]
# We begin by setting up some benchmarks for prices and budgets, so
#     the things we don&rsquo;t want to change we can hold fixed.

# %%
from example_nutrition import pbar, my_prices

# %% [markdown]
# #### Budgets

# %% [markdown]
# Get food budget for all households, then find median budget:

# %%
import numpy as np

xhat = mlw.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
x0 = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# %% [markdown]
# ### Simple Policy Experiments: Changing Prices

# %% [markdown]
# If price of a good increases/decreases, what&rsquo;s the cost to the
# household?  Ask a related question: If a price $p_1$ increases, how
# much *income* do we need to give to the household to make it just as
# well off as it was at the old prices?
#
# Summarize this as the  *compensating variation* associated with the
# price change.
#
# ![img](./compensating_variation.png)
#
# Compensating Variation can also be measured as the (change in the)
# area under the **Hicksian** (or **compensated**) demand curve:
#
# ![img](./compensating_variation_newexpenditure.png).

# %% [markdown]
# #### Marshallian vs. Hicksian Demand Curves

# %% [markdown]
# Let&rsquo;s look at Marshallian & Hicksian demands&#x2014;one way of thinking
# about the Hicksian (compensated) curves is that they  eliminate the
# income effect associated with changing prices.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print([k for k in pbar.index])

my_j = 'maize ufa mgaiwa (normal flour)'  # Interesting Ugandan staple

P = np.geomspace(.01,10,50)*pbar[my_j]

print(mlw.demands(x0,my_prices(my_j,P[0])))


# Utility of median household, given prices
U0 = mlw.indirect_utility(x0,pbar)


plt.plot([mlw.demands(x0,my_prices(my_j,p0))['Maize ufa mgaiwa (normal flour)'] for p0 in P],P)
plt.plot([mlw.demands(U0,my_prices(my_j,p0),type="Hicksian")['Maize ufa mgaiwa (normal flour)'] for p0 in P],P)
plt.ylabel('Price')
plt.xlabel(my_j)
plt.legend(("Marshallian","Hicksian"))
# Out:
# ['avocado', 'banana', 'bean, brown', 'beef', 'biscuits', 'bread', 'buns, scones', 'cabbage', 'cassava tubers', 'chicken - whole', 'chinese cabbage', 'chips (vendor)', 'citrus – naartje, orange, etc', 'cooking oil', 'eggs', 'fresh fish (medium variety)', 'fresh fish (small variety)', 'fresh milk', 'fruit juice', 'goat', 'green maize', 'groundnut (shelled)', 'groundnut flour', 'irish potato', 'maize - boiled or roasted (vendor)', 'maize ufa mgaiwa (normal flour)', 'maize ufa refined (fine flour)', 'mandazi, doughnut (vendor)', 'margarine - blue band', 'nkhwani', 'okra / therere', 'onion', 'orange sweet potato', 'other cultivated green leafy vegetables', 'popcorn', 'powdered milk', 'rice', 'salt', 'samosa (vendor)', 'smoked fish (medium variety)', 'smoked fish (small variety)', 'soft drinks (coca-cola, fanta, sprite, etc)', 'soyabean flour', 'spaghetti, macaroni, pasta', 'spices', 'squash (sobo drink concentrate)', 'sugar', 'sugar cane', 'sun dried fish (large variety)', 'sun dried fish (medium variety)', 'sun dried fish (small variety)', 'sweets, candy, chocolates', 'tanaposi/rape', 'tea', 'thobwa', 'tomato', 'white sweet potato', 'wild fruit (masau, malambe, etc)', 'yeast, baking powder, bicarbonate of soda', 'yoghurt']
# j
# Avocado                                        1.020240
# Banana                                         0.826621
# Bean, brown                                    0.775861
# Beef                                           0.821772
# Biscuits                                       0.170391
# Bread                                          0.913989
# Buns, scones                                   0.549789
# Cabbage                                        1.212865
# Cassava tubers                                 1.215383
# Chicken - whole                                0.877407
# Chinese cabbage                                0.669072
# Chips (vendor)                                 0.485987
# Citrus – naartje, orange, etc                  0.468251
# Cooking oil                                    0.420361
# Eggs                                           0.457871
# Fresh fish (medium variety)                    0.376314
# Fresh fish (small variety)                     0.435232
# Fresh milk                                     0.711412
# Fruit juice                                    1.050222
# Goat                                           0.722382
# Green maize                                    1.305248
# Groundnut (shelled)                            0.367813
# Groundnut flour                                0.198593
# Irish potato                                   1.906705
# Maize - boiled or roasted (vendor)             0.652857
# Maize ufa mgaiwa (normal flour)                1.151282
# Maize ufa refined (fine flour)                 1.579997
# Mandazi, doughnut (vendor)                     0.370097
# Margarine - blue band                          0.548533
# Nkhwani                                        0.663940
# Okra / therere                                 0.979159
# Onion                                          0.233912
# Orange sweet potato                            1.666334
# Other cultivated green leafy vegetables        0.665140
# Popcorn                                        0.103482
# Powdered milk                                  0.023873
# Rice                                           1.497608
# Salt                                           0.741300
# Samosa (vendor)                                0.084139
# Smoked fish (medium variety)                   0.324629
# Smoked fish (small variety)                    0.250236
# Soft drinks (coca-cola, fanta, sprite, etc)    2.367554
# Soyabean flour                                 0.765378
# Spaghetti, macaroni, pasta                     0.622443
# Spices                                         0.146295
# Squash (sobo drink concentrate)                1.081440
# Sugar                                          0.851492
# Sugar cane                                     2.374152
# Sun dried fish (large variety)                 0.634038
# Sun dried fish (medium variety)                0.237874
# Sun dried fish (small variety)                 0.310435
# Sweets, candy, chocolates                      0.791196
# Tanaposi/rape                                  0.785342
# Tea                                            0.132284
# Thobwa                                         1.197038
# Tomato                                         1.176142
# White sweet potato                             1.644061
# Wild fruit (masau, malambe, etc)               0.403679
# Yeast, baking powder, bicarbonate of soda      0.102580
# Yoghurt                                        0.623619
# Name: quantities, dtype: float64

# %% [markdown]
# #### Welfare measures

# %%
def compensating_variation(U0,p0,p1):
    p1.index = [x.lower().strip() for x in p1.index]
    p0.index = [x.lower().strip() for x in p0.index]
    x0 = mlw.expenditure(U0,p0)
    x1 = mlw.expenditure(U0,p1)

    return x1-x0

def revenue(U0,p0,p1,type='Marshallian'):
    """(Un)Compensated revenue from taxes changing vector of prices from p0 to p1.

    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """

    p1.index = [x.lower().strip() for x in p1.index]
    p0.index = [x.lower().strip() for x in p0.index]
    
    dp = p1 - p0 # Change in prices

    c = mlw.demands(U0,p1,type=type)

    c.index = [x.lower().strip() for x in c.index]

    dp,c = dp.align(c,join='inner')

    return dp.T@c


def deadweight_loss(U0,p0,p1):
    """
    Deadweight loss of tax/subsidy scheme creating wedge in prices from p0 to p1.

    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """
    cv = compensating_variation(U0,p0,p1)

    return cv - revenue(U0,p0,p1,type='Hicksian')

# %% [markdown]
# #### Price Changes, Revenue, and Compensating Variation

# %% [markdown]
# Examine effects of price changes on revenue (if price change due to a
# tax or subsidy) and compensating variation.

# %%
fig, ax1 = plt.subplots()

ax1.plot(P,[compensating_variation(U0,pbar,my_prices(my_j,p0)) for p0 in P])
ax1.set_xlabel(f"Price of {my_j}")
ax1.set_ylabel("Compensating Variation")

ax1.plot(P,[revenue(U0,pbar,my_prices(my_j,p0),type='Hicksian') for p0 in P],'k')
ax1.legend(('Compensating Variation','Revenue'))
ax1.axhline(0)
ax1.axvline(pbar.loc[my_j])

# %%
p_test = my_prices(my_j, p0)
print(mlw.expenditure(U0, p_test))
print(mlw.demands(U0, p_test, type='Hicksian'))
# Out:
# 39895.021166071114
# j
# Avocado                                        1.007590
# Banana                                         0.811813
# Bean, brown                                    0.771142
# Beef                                           0.812387
# Biscuits                                       0.167024
# Bread                                          0.904955
# Buns, scones                                   0.544556
# Cabbage                                        1.205082
# Cassava tubers                                 1.202885
# Chicken - whole                                0.873000
# Chinese cabbage                                0.665541
# Chips (vendor)                                 0.481337
# Citrus – naartje, orange, etc                  0.459187
# Cooking oil                                    0.414578
# Eggs                                           0.452859
# Fresh fish (medium variety)                    0.371799
# Fresh fish (small variety)                     0.430506
# Fresh milk                                     0.701122
# Fruit juice                                    1.022803
# Goat                                           0.715197
# Green maize                                    1.290969
# Groundnut (shelled)                            0.363417
# Groundnut flour                                0.196397
# Irish potato                                   1.874887
# Maize - boiled or roasted (vendor)             0.645709
# Maize ufa mgaiwa (normal flour)                0.984092
# Maize ufa refined (fine flour)                 1.573829
# Mandazi, doughnut (vendor)                     0.366011
# Margarine - blue band                          0.545848
# Nkhwani                                        0.660507
# Okra / therere                                 0.974022
# Onion                                          0.230359
# Orange sweet potato                            1.652089
# Other cultivated green leafy vegetables        0.661524
# Popcorn                                        0.102208
# Powdered milk                                  0.023508
# Rice                                           1.480397
# Salt                                           0.739094
# Samosa (vendor)                                0.082830
# Smoked fish (medium variety)                   0.322197
# Smoked fish (small variety)                    0.248022
# Soft drinks (coca-cola, fanta, sprite, etc)    2.338004
# Soyabean flour                                 0.757082
# Spaghetti, macaroni, pasta                     0.617433
# Spices                                         0.144942
# Squash (sobo drink concentrate)                1.076737
# Sugar                                          0.842258
# Sugar cane                                     2.351131
# Sun dried fish (large variety)                 0.625961
# Sun dried fish (medium variety)                0.235668
# Sun dried fish (small variety)                 0.307851
# Sweets, candy, chocolates                      0.774309
# Tanaposi/rape                                  0.780209
# Tea                                            0.131206
# Thobwa                                         1.184290
# Tomato                                         1.159557
# White sweet potato                             1.632834
# Wild fruit (masau, malambe, etc)               0.400327
# Yeast, baking powder, bicarbonate of soda      0.101534
# Yoghurt                                        0.614999
# Name: quantities, dtype: float64

# %%
print(P)
# Out:
# [   4.21108762    4.84862691    5.58268671    6.4278798     7.40103123
#     8.52151331    9.81163122   11.29706704   13.00739102   14.97665018
#    17.24404611   19.85471536   22.86062792   26.32162181   30.30659425
#    34.89487319   40.17779646   46.26052999   53.26416141   61.32811039
#    70.61290415   81.30337298   93.61232959  107.78480562  124.1029293
#   142.89154184  164.52466388  189.43294107  218.11221683  251.13340299
#   289.15384482  332.93040662  383.33453848  441.36962401  508.19095449
#   585.12872698  673.71452425  775.71180369  893.15100197 1028.36995457
#  1184.0604345  1363.3217368  1569.72237556 1807.37112144 2080.9987941
#  2396.05243753 2758.80375312 3176.47394898 3657.37749094 4211.08761667]

# %%
cv_values = [compensating_variation(U0, pbar, my_prices(my_j, p0)) for p0 in P]
rev_values = [revenue(U0, pbar, my_prices(my_j, p0), type='Hicksian') for p0 in P]

print(cv_values)
print(rev_values)
# Out:
# [np.float64(-441.75042857951485), np.float64(-441.017927801724), np.float64(-440.1772209923729), np.float64(-439.2123237771302), np.float64(-438.1048905829957), np.float64(-436.8338657995264), np.float64(-435.37508343177615), np.float64(-433.7008076590064), np.float64(-431.77920548013935), np.float64(-429.5737414725372), np.float64(-427.0424831365235), np.float64(-424.1373036490986), np.float64(-420.8029667970841), np.float64(-416.9760768306369), np.float64(-412.5838729853276), np.float64(-407.54284623239073), np.float64(-401.7571513708099), np.float64(-395.11678481978015), np.float64(-387.4954929995365), np.float64(-378.7483719347365), np.float64(-368.7091121136473), np.float64(-357.1868363925896), np.float64(-343.9624708064657), np.float64(-328.78457923397946), np.float64(-311.3645827082437), np.float64(-291.37127256098756), np.float64(-268.4245129156552), np.float64(-242.08801296833553), np.float64(-211.86103138166072), np.float64(-177.16885532860033), np.float64(-137.35187284178392), np.float64(-91.6530308560541), np.float64(-39.20344035878952), np.float64(20.994145125448995), np.float64(90.08429197772057), np.float64(169.38065042782546), np.float64(260.3909340195023), np.float64(364.8455898503744), np.float64(484.73070484883647), np.float64(622.32577427254), np.float64(780.2470509095074), np.float64(961.4973001428734), np.float64(1169.5229074504095), np.float64(1408.279425668632), np.float64(1682.306809601956), np.float64(1996.815770709538), np.float64(2357.786896444508), np.float64(2772.0844223398235), np.float64(3247.5868249128907), np.float64(3793.336724447676)]
# [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %% [markdown]
# #### Deadweight Loss

# %% [markdown]
# Differences between revenue and compensating variation is deadweight-loss:

# %%
fig, ax1 = plt.subplots()

ax1.plot(P,[deadweight_loss(U0,pbar,my_prices(my_j,p0)) for p0 in P])
ax1.set_xlabel("Price of %s" % my_j)
ax1.set_ylabel("Deadweight Loss")
# Out:
# Text(0, 0.5, 'Deadweight Loss')
